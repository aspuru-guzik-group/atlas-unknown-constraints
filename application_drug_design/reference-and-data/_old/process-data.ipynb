# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib
# %matplotlib inline
import seaborn as sns

sns.set(style='ticks', context='notebook', font_scale=1.2)
from gryffin import Gryffin

# %%
df = pd.read_csv('data.csv', index_col="Compound")
df = df.rename(columns=lambda x: x.strip())
df
# Out:
#                                                      SMILES        R1  \
# Compound
# 1         O=C(CCCCC)N[C@@H](C1=CC=C(OCC2=CC=CC=C2)C=C1)C...  O=CCCCCC
# 2         O=C(CCCCC)N[C@@H](C1=CC=C(OCC2=CC=CC=C2)C=C1)C...  O=CCCCCC
# 3         O=C(CCCCC)N[C@@H](C1=CC=C(OCC2=CC=CC=C2)C=C1)C...  O=CCCCCC
# 4         O=C(CCCCC)N[C@@H](C1=CC=C(OCC2=CC=CC=C2)C=C1)C...  O=CCCCCC
# 5         O=C(CCCCC)N[C@@H](C1=CC=C(OCC2=CC=CC=C2)C=C1)C...  O=CCCCCC
# ...                                                     ...       ...
# 147       O=C(NCCC1=CC=C(C(O)=O)C=C1)OCC2C(C=CC=C3)=C3C4...       NaN
# 148       O=C(NC1=CC=C(CC(O)=O)C=C1)OCC2C(C=CC=C3)=C3C4=...       NaN
# 149       O=C(NC1=CC=C(CO)C=C1)OCC2C(C=CC=C3)=C3C4=C2C=C...       NaN
# 150       O=C(NCCC1=CC=C(O)C=C1)OCC2C(C=CC=C3)=C3C4=C2C=...       NaN
# 151       O=C(NCC1=CC=C(N)C=C1)OCC2C(C=CC=C3)=C3C4=C2C=C...       NaN
#
#                                              R2                 R3  \
# Compound
# 1         N[C@H](C=O)C1=CC=C(C=C1)OCC2=CC=CC=C2           N1CCCCC1
# 2         N[C@H](C=O)C1=CC=C(C=C1)OCC2=CC=CC=C2      NCC(/C=C)=C/C
# 3         N[C@H](C=O)C1=CC=C(C=C1)OCC2=CC=CC=C2     NCCC1=CC=CC=C1
# 4         N[C@H](C=O)C1=CC=C(C=C1)OCC2=CC=CC=C2  NCC1=CC=C(C=C1)Cl
# 5         N[C@H](C=O)C1=CC=C(C=C1)OCC2=CC=CC=C2   NC1=CC=C(C=C1)OC
# ...                                         ...                ...
# 147                                         NaN                NaN
# 148                                         NaN                NaN
# 149                                         NaN                NaN
# 150                                         NaN                NaN
# 151                                         NaN                NaN
#
#          DENV % @ 50 uM WNV % @ 50 uM DENV2proHeLa % @ 12.5 uM  \
# Compound
# 1                  n.i.  19.7 +/- 4.2             58.3 +/- 6.8
# 2                  n.i.          n.i.                     n.i.
# 3                  n.i.  15.1 +/- 1.9                     n.d.
# 4                  n.i.          n.i.             13.8 +/- 7.5
# 5                  n.i.          n.i.             10.2 +/- 3.5
# ...                 ...           ...                      ...
# 147                 NaN           NaN                      NaN
# 148                 NaN           NaN                      NaN
# 149                 NaN           NaN                      NaN
# 150                 NaN           NaN                      NaN
# 151                 NaN           NaN                      NaN
#
#          DENV2proHeLa EC50 (uM)     CC50 (uM) thrombin % @ 25 uM  \
# Compound
# 1                  12.6 +/- 1.4  28.8 +/- 3.2       10.0 +/- 4.8
# 2                          n.d.          > 50               n.i.
# 3                          n.d.        < 12.5               n.i.
# 4                          n.d.          > 50               n.i.
# 5                          n.d.          > 25               n.i.
# ...                         ...           ...                ...
# 147                         NaN           NaN                NaN
# 148                         NaN           NaN                NaN
# 149                         NaN           NaN                NaN
# 150                         NaN           NaN                NaN
# 151                         NaN           NaN                NaN
#
#          trypsin % @ 50 uM virus titer reduction assay % @ 12.5 uM  \
# Compound
# 1                     n.i.                                     NaN
# 2                     n.i.                                     NaN
# 3                     n.i.                                     NaN
# 4                     n.i.                                     NaN
# 5                     n.i.                                     NaN
# ...                    ...                                     ...
# 147                    NaN                                     NaN
# 148                    NaN                                     NaN
# 149                    NaN                                     NaN
# 150                    NaN                                     NaN
# 151                    NaN                                     NaN
#
#           virus titer reduction assay EC50 (uM)
# Compound
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
# 5                                           NaN
# ...                                         ...
# 147                                         NaN
# 148                                         NaN
# 149                                         NaN
# 150                                         NaN
# 151                                         NaN
#
# [150 rows x 13 columns]

# %%
R1 = df.loc[:, "R1"].unique()
R2 = df.loc[:, "R2"].unique()
R3 = df.loc[:, "R3"].unique()

# %%
len(R1), len(R2), len(R3), len(R1) * len(R2) * len(R3)
# Out:
# (45, 15, 27, 18225)
